# %%
# Importing necessary libraries
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('Iris.csv')

# %%
data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
data.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
data.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
x=data[['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']]
y=data['Species']

# %%
x
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0              5.1           3.5            1.4           0.2
# 1              4.9           3.0            1.4           0.2
# 2              4.7           3.2            1.3           0.2
# 3              4.6           3.1            1.5           0.2
# 4              5.0           3.6            1.4           0.2
# ..             ...           ...            ...           ...
# 145            6.7           3.0            5.2           2.3
# 146            6.3           2.5            5.0           1.9
# 147            6.5           3.0            5.2           2.0
# 148            6.2           3.4            5.4           2.3
# 149            5.9           3.0            5.1           1.8
#
# [150 rows x 4 columns]

# %%
y
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: Species, Length: 150, dtype: object

# %%
# Splitting the dataset into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=23)

# %%
x_train
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 146            6.3           2.5            5.0           1.9
# 106            4.9           2.5            4.5           1.7
# 131            7.9           3.8            6.4           2.0
# 34             4.9           3.1            1.5           0.1
# 99             5.7           2.8            4.1           1.3
# ..             ...           ...            ...           ...
# 39             5.1           3.4            1.5           0.2
# 91             6.1           3.0            4.6           1.4
# 31             5.4           3.4            1.5           0.4
# 40             5.0           3.5            1.3           0.3
# 83             6.0           2.7            5.1           1.6
#
# [105 rows x 4 columns]

# %%
x_test
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 139            6.9           3.1            5.4           2.1
# 125            7.2           3.2            6.0           1.8
# 67             5.8           2.7            4.1           1.0
# 3              4.6           3.1            1.5           0.2
# 113            5.7           2.5            5.0           2.0
# 52             6.9           3.1            4.9           1.5
# 18             5.7           3.8            1.7           0.3
# 137            6.4           3.1            5.5           1.8
# 20             5.4           3.4            1.7           0.2
# 64             5.6           2.9            3.6           1.3
# 73             6.1           2.8            4.7           1.2
# 30             4.8           3.1            1.6           0.2
# 102            7.1           3.0            5.9           2.1
# 19             5.1           3.8            1.5           0.3
# ...

# %%
y_train
# Out:
# 146     Iris-virginica
# 106     Iris-virginica
# 131     Iris-virginica
# 34         Iris-setosa
# 99     Iris-versicolor
#             ...
# 39         Iris-setosa
# 91     Iris-versicolor
# 31         Iris-setosa
# 40         Iris-setosa
# 83     Iris-versicolor
# Name: Species, Length: 105, dtype: object

# %%
y_test
# Out:
# 139     Iris-virginica
# 125     Iris-virginica
# 67     Iris-versicolor
# 3          Iris-setosa
# 113     Iris-virginica
# 52     Iris-versicolor
# 18         Iris-setosa
# 137     Iris-virginica
# 20         Iris-setosa
# 64     Iris-versicolor
# 73     Iris-versicolor
# 30         Iris-setosa
# 102     Iris-virginica
# 19         Iris-setosa
# 10         Iris-setosa
# 133     Iris-virginica
# 51     Iris-versicolor
# 63     Iris-versicolor
# 135     Iris-virginica
# 28         Iris-setosa
# 115     Iris-virginica
# 45         Iris-setosa
# 46         Iris-setosa
# 2          Iris-setosa
# 140     Iris-virginica
# 17         Iris-setosa
# 44         Iris-setosa
# 126     Iris-virginica
# 75     Iris-versicolor
# 69     Iris-versicolor
# 9          Iris-setosa
# 59     Iris-versicolor
# 16         Iris-setosa
# 122     Iris-virginica
# 7          Iris-setosa
# 5          Iris-setosa
# 54     Iris-versicolor
# 93     Iris-versicolor
# 95     Iris-versicolor
# 100     Iris-virginica
# ...

# %%
# Applying K-Nearest Neighbors (KNN)
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
# Making predictions on the test set
y_pred = knn.predict(x_test)

# %%
y_pred
# Out:
# array(['Iris-virginica', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-setosa', 'Iris-virginica', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-virginica', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-virginica', 'Iris-setosa',
#        'Iris-setosa', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-setosa',
#        'Iris-virginica', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-virginica', 'Iris-setosa', 'Iris-setosa', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-virginica', 'Iris-setosa',
#        'Iris-setosa', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-virginica',
#        'Iris-setosa', 'Iris-versicolor', 'Iris-setosa', 'Iris-versicolor'],
#       dtype=object)

# %%
# Evaluating the model
accuracy = accuracy_score(y_test, y_pred)
classification_rep = classification_report(y_test, y_pred)

# %%
accuracy
# Out:
# 0.9777777777777777

# %%
accuracy_score
# Out:
# <function sklearn.metrics._classification.accuracy_score(y_true, y_pred, *, normalize=True, sample_weight=None)>

# %%
# Visualizing the dataset with a pair plot
sns.set(style="whitegrid")
# Pairplot to visualize the dataset
sns.pairplot(data, hue='Species', palette="Set2")
plt.show()

# %%
# Creating scatter plots for different pairs of features
plt.figure(figsize=(15, 10))

# Scatter plot for Sepal Length vs Sepal Width
plt.subplot(2, 2, 1)
sns.scatterplot(data=data, x=data['SepalLengthCm'], y=data['SepalWidthCm'], hue=data['Species'], palette='Set2')
plt.title('Sepal Length vs Sepal Width')

# Scatter plot for Petal Length vs Petal Width
plt.subplot(2, 2, 2)
sns.scatterplot(data=data, x=data['PetalLengthCm'], y=data['PetalWidthCm'], hue=data['Species'], palette='Set2')
plt.title('Petal Length vs Petal Width')

# Scatter plot for Sepal Length vs Petal Length
plt.subplot(2, 2, 3)
sns.scatterplot(data=data, x=data['SepalLengthCm'], y=data['PetalLengthCm'], hue=data['Species'], palette='Set2')
plt.title('Sepal Length vs Petal Length')

# Scatter plot for Sepal Width vs Petal Width
plt.subplot(2, 2, 4)
sns.scatterplot(data=data, x=data['SepalWidthCm'], y=data['PetalWidthCm'], hue=data['Species'], palette='Set2')
plt.title('Sepal Width vs Petal Width')

plt.tight_layout()
plt.show()
